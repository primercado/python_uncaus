# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
barrios = pd.read_csv('2022-07-13_info_publica.csv')
barrios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5687 entries, 0 to 5686
# Data columns (total 77 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   id_renabap                                                       5687 non-null   int64
#  1   geometry                                                         5687 non-null   object
#  2   renabap_id                                                       5687 non-null   int64
#  3   nombre_barrio                                                    5687 non-null   object
#  4   provincia                                                        5687 non-null   object
#  5   departamento                                                     5687 non-null   object
#  6   localidad                                                        5687 non-null   object
# ...

# %%
barrios['provincia'].value_counts()*100/len(barrios['provincia'])
# Out:
# Buenos Aires                       33.989801
# Santa Fe                            7.174257
# Chaco                               7.051169
# Misiones                            6.593986
# Mendoza                             5.574116
# Tucumán                             5.240021
# Córdoba                             4.941094
# Salta                               4.097063
# Entre Ríos                          3.727800
# Río Negro                           3.657464
# Corrientes                          3.516793
# Jujuy                               2.479339
# Formosa                             1.951820
# Neuquén                             1.793564
# Santiago del Estero                 1.635309
# San Juan                            1.494637
# Chubut                              1.230877
# Ciudad Autónoma de Buenos Aires     0.879198
# Tierra del Fuego                    0.826446
# Catamarca                           0.720943
# San Luis                            0.527519
# ...

# %%
chaco = barrios[barrios['provincia'] == 'Chaco']
chaco
# Out:
#       id_renabap                                           geometry  \
# 2035        2204  MULTIPOLYGON (((-58.94786172227644 -27.5126730...
# 2036        2205  MULTIPOLYGON (((-58.95806414479626 -27.4625867...
# 2037        2206  MULTIPOLYGON (((-58.95953820123104 -27.4630058...
# 2038        2207  MULTIPOLYGON (((-58.94339372157568 -27.5185641...
# 2039        2208  MULTIPOLYGON (((-58.957093 -27.507206, -58.955...
# ...          ...                                                ...
# 4742        5109  MULTIPOLYGON (((-60.40082779035269 -27.2941863...
# 4743        5110  MULTIPOLYGON (((-60.41816291015152 -27.2801269...
# 4744        5111  MULTIPOLYGON (((-60.42047016746261 -27.2959256...
# 4745        5112  MULTIPOLYGON (((-59.51197844820855 -26.9355293...
# 4746        5113  MULTIPOLYGON (((-59.63892725373329 -26.6962153...
#
#       renabap_id                  nombre_barrio provincia     departamento  \
# ...

# %%
chaco['departamento'].value_counts()
# Out:
# San Fernando                     183
# General Güemes                    37
# Almirante Brown                   23
# Comandante Fernández              19
# Mayor Luis J. Fontana             17
# Libertador General San Martín     16
# Independencia                     14
# Maipú                             13
# 25 de mayo                        10
# General Belgrano                   8
# Bermejo                            7
# San Lorenzo                        7
# 9 de julio                         6
# Libertad                           6
# Quitilipi                          5
# 1° de Mayo                         5
# Chacabuco                          5
# 12 de octubre                      4
# Fray Justo Santa María de Oro      4
# General Donovan                    3
# Presidencia de la Plaza            3
# 2 de abril                         2
# O'Higgins                          2
# Sargento Cabral                    2
# Name: departamento, dtype: int64

# %%
chaco_guemes = chaco[chaco['departamento'] == 'General Güemes']
chaco_guemes
# Out:
#      id_renabap                                           geometry  \
# 201        3800  MULTIPOLYGON (((-60.633038 -25.933384, -60.633...
# 202        3801  MULTIPOLYGON (((-60.62953693013097 -25.9401491...
# 203        3802  MULTIPOLYGON (((-60.64064869213973 -25.9325697...
# 204        3803  MULTIPOLYGON (((-60.64212529890826 -25.9455916...
# 205        3804  MULTIPOLYGON (((-60.64296252492487 -25.9491521...
# 206        3805  MULTIPOLYGON (((-60.63664818537112 -25.9567018...
# 207        3806  MULTIPOLYGON (((-60.622754 -25.954377, -60.621...
# 208        3807  MULTIPOLYGON (((-60.63513906678358 -25.9639678...
# 209        3808  MULTIPOLYGON (((-60.63075028995631 -25.9678003...
# 210        3809  MULTIPOLYGON (((-60.61396069427951 -25.9641669...
# 211        3810  MULTIPOLYGON (((-60.635548 -25.933285, -60.633...
# 246        3846  MULTIPOLYGON (((-60.6406083151593 -25.93255159...
# 252        3853  MULTIPOLYGON (((-60.60756431612665 -25.9326327...
# ...

# %%
chaco_guemes.reset_index(drop = True, inplace=True)
chaco_guemes
# Out:
#     id_renabap                                           geometry  renabap_id  \
# 0         3800  MULTIPOLYGON (((-60.633038 -25.933384, -60.633...        3800
# 1         3801  MULTIPOLYGON (((-60.62953693013097 -25.9401491...        3801
# 2         3802  MULTIPOLYGON (((-60.64064869213973 -25.9325697...        3802
# 3         3803  MULTIPOLYGON (((-60.64212529890826 -25.9455916...        3803
# 4         3804  MULTIPOLYGON (((-60.64296252492487 -25.9491521...        3804
# 5         3805  MULTIPOLYGON (((-60.63664818537112 -25.9567018...        3805
# 6         3806  MULTIPOLYGON (((-60.622754 -25.954377, -60.621...        3806
# 7         3807  MULTIPOLYGON (((-60.63513906678358 -25.9639678...        3807
# 8         3808  MULTIPOLYGON (((-60.63075028995631 -25.9678003...        3808
# 9         3809  MULTIPOLYGON (((-60.61396069427951 -25.9641669...        3809
# 10        3810  MULTIPOLYGON (((-60.635548 -25.933285, -60.633...        3810
# ...

# %%
chaco_guemes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 77 columns):
#  #   Column                                                           Non-Null Count  Dtype
# ---  ------                                                           --------------  -----
#  0   id_renabap                                                       37 non-null     int64
#  1   geometry                                                         37 non-null     object
#  2   renabap_id                                                       37 non-null     int64
#  3   nombre_barrio                                                    37 non-null     object
#  4   provincia                                                        37 non-null     object
#  5   departamento                                                     37 non-null     object
#  6   localidad                                                        37 non-null     object
# ...

# %%
chaco_guemes.groupby(['localidad']).cantidad_viviendas_aproximadas.sum()
# Out:
# localidad
# El Sauzalito            247.0
# Juan José Castelli     1623.0
# Miraflores              336.0
# Nueva Pompeya           195.0
# Villa Río Bermejito     109.0
# Name: cantidad_viviendas_aproximadas, dtype: float64

# %%
chaco_guemes.groupby(['localidad']).cantidad_familias_aproximada.sum()
# Out:
# localidad
# El Sauzalito            273.0
# Juan José Castelli     1787.0
# Miraflores              369.0
# Nueva Pompeya           215.0
# Villa Río Bermejito     120.0
# Name: cantidad_familias_aproximada, dtype: float64

# %%
chaco_guemes.groupby(['localidad']).nombre_barrio.value_counts()
# Out:
# localidad            nombre_barrio
# El Sauzalito         El Portal              1
#                      Federacion             1
#                      Puerto Sol             1
#                      SECHEEP                1
#                      Sin Nombre             1
#                      Wichi                  1
# Juan José Castelli   Cancha Aviación        1
#                      Chacra 27/28           1
#                      Chacra 31              1
#                      Chacra 4               1
#                      Chacra 5               1
#                      Chacra 64              1
#                      Chacra 65              1
#                      Chacra 7               1
#                      Chacra 79              1
#                      Diecinueve de Abril    1
#                      Opo                    1
#                      Quinta 14              1
#                      Quinta 24              1
#                      Reserva                1
# ...

# %%
castelli = chaco_guemes[chaco_guemes['localidad'] == 'Juan José Castelli']
castelli.reset_index(drop = True, inplace=True)

# %%
for nombre in castelli['nombre_barrio']:
    print (nombre)
# Out:
# Chacra 7
# Reserva Norte
# Chacra 4
# Quinta 14
# Chacra 27/28
# Chacra 65
# Reserva Sur
# Opo
# Chacra 64
# Chacra 79
# Reserva
# Chacra 5
# Chacra 31
# Diecinueve de Abril
# Quinta 24
# Cancha Aviación

# %%
castelli.groupby(['nombre_barrio']).cantidad_viviendas_aproximadas.sum().sort_values(ascending=False)
# Out:
# nombre_barrio
# Cancha Aviación        250.0
# Chacra 27/28           225.0
# Chacra 5               200.0
# Reserva Sur            150.0
# Reserva                100.0
# Chacra 31               90.0
# Chacra 4                90.0
# Chacra 79               80.0
# Quinta 24               80.0
# Chacra 7                73.0
# Chacra 65               70.0
# Opo                     60.0
# Reserva Norte           60.0
# Quinta 14               45.0
# Chacra 64               35.0
# Diecinueve de Abril     15.0
# Name: cantidad_viviendas_aproximadas, dtype: float64

# %%
castelli.groupby(['nombre_barrio']).cantidad_familias_aproximada.sum().sort_values(ascending=False)
# Out:
# nombre_barrio
# Cancha Aviación        275.0
# Chacra 27/28           248.0
# Chacra 5               220.0
# Reserva Sur            165.0
# Reserva                110.0
# Chacra 31               99.0
# Chacra 4                99.0
# Chacra 79               88.0
# Quinta 24               88.0
# Chacra 7                80.0
# Chacra 65               77.0
# Opo                     66.0
# Reserva Norte           66.0
# Quinta 14               50.0
# Chacra 64               39.0
# Diecinueve de Abril     17.0
# Name: cantidad_familias_aproximada, dtype: float64

# %%
castelli.columns
# Out:
# Index(['id_renabap', 'geometry', 'renabap_id', 'nombre_barrio', 'provincia',
#        'departamento', 'localidad', 'cantidad_viviendas_aproximadas',
#        'cantidad_familias_aproximada', 'decada_de_creacion',
#        'anio_de_creacion', 'energia_electrica', 'efluentes_cloacales',
#        'agua_corriente', 'cocina', 'calefaccion', 'situacion_dominial',
#        'clasificacion_barrio', 'superficie_m2', 'personas_genero_masc',
#        'personas_genero_fem', 'personas_genero_otrx',
#        'responsable_genero_masc', 'responsable_genero_fem',
#        'familia_monoparental_responsable_masculino',
#        'familia_monoparental_responsable_femenino',
#        'cantidad_certificados_entregados',
#        'recibe_asignacion_universal_por_hijo',
#        'no_recibe_asignacion_universal_por_hijo',
#        'no_sabe_si_recibe_asignacion_universal_por_hijo',
#        'tipo_propiedad_de_quienes_vieven_en_ella', 'tipo_propiedad_alquilada',
# ...

# %%
servicios = castelli[['nombre_barrio', 'superficie_m2','energia_electrica', 'efluentes_cloacales',
       'agua_corriente', 'cocina', 'calefaccion', 'situacion_dominial',
       'clasificacion_barrio']]
servicios
# Out:
#           nombre_barrio  superficie_m2  \
# 0              Chacra 7          52999
# 1         Reserva Norte          24646
# 2              Chacra 4          46258
# 3             Quinta 14          44124
# 4          Chacra 27/28         137932
# 5             Chacra 65          48350
# 6           Reserva Sur         155662
# 7                   Opo          46301
# 8             Chacra 64          18723
# 9             Chacra 79          45903
# 10              Reserva          76069
# 11             Chacra 5         127931
# 12            Chacra 31          93642
# 13  Diecinueve de Abril           5102
# 14            Quinta 24          49360
# 15      Cancha Aviación         125429
#
#                                     energia_electrica  \
# 0   Conexión formal a la red con medidor domicilia...
# 1                         Conexión irregular a la red
# 2                         Conexión irregular a la red
# 3                         Conexión irregular a la red
# ...

# %%
castelli.groupby(['nombre_barrio']).personas_genero_fem.sum()
# Out:
# nombre_barrio
# Cancha Aviación          0
# Chacra 27/28           232
# Chacra 31              137
# Chacra 4               136
# Chacra 5               269
# Chacra 64               40
# Chacra 65               71
# Chacra 7                36
# Chacra 79              101
# Diecinueve de Abril     29
# Opo                     78
# Quinta 14               43
# Quinta 24              124
# Reserva                141
# Reserva Norte           62
# Reserva Sur            181
# Name: personas_genero_fem, dtype: int64

# %%
castelli.groupby(['nombre_barrio']).personas_genero_masc.sum()
# Out:
# nombre_barrio
# Cancha Aviación          0
# Chacra 27/28           181
# Chacra 31              135
# Chacra 4               146
# Chacra 5               249
# Chacra 64               34
# Chacra 65               89
# Chacra 7                50
# Chacra 79               90
# Diecinueve de Abril     21
# Opo                     82
# Quinta 14               47
# Quinta 24               99
# Reserva                134
# Reserva Norte           77
# Reserva Sur            193
# Name: personas_genero_masc, dtype: int64

# %%
castelli.groupby(['nombre_barrio']).personas_genero_otrx.sum()
# Out:
# nombre_barrio
# Cancha Aviación        0
# Chacra 27/28           0
# Chacra 31              0
# Chacra 4               0
# Chacra 5               0
# Chacra 64              0
# Chacra 65              0
# Chacra 7               1
# Chacra 79              0
# Diecinueve de Abril    0
# Opo                    0
# Quinta 14              0
# Quinta 24              0
# Reserva                0
# Reserva Norte          0
# Reserva Sur            0
# Name: personas_genero_otrx, dtype: int64

# %%
castelli.groupby(['nombre_barrio']).personas_genero_fem.sum()

castelli_total_pobladores = castelli['personas_genero_fem'] + castelli['personas_genero_masc'] + castelli['personas_genero_otrx']

castelli_total_pobladores
# Out:
# 0      87
# 1     139
# 2     282
# 3      90
# 4     413
# 5     160
# 6     374
# 7     160
# 8      74
# 9     191
# 10    275
# 11    518
# 12    272
# 13     50
# 14    223
# 15      0
# dtype: int64

# %%
castelli[['nombre_barrio','cantidad_familias_aproximada', 'recibe_asignacion_universal_por_hijo',
       'no_recibe_asignacion_universal_por_hijo',
       'no_sabe_si_recibe_asignacion_universal_por_hijo']]
# Out:
#           nombre_barrio  cantidad_familias_aproximada  \
# 0              Chacra 7                          80.0
# 1         Reserva Norte                          66.0
# 2              Chacra 4                          99.0
# 3             Quinta 14                          50.0
# 4          Chacra 27/28                         248.0
# 5             Chacra 65                          77.0
# 6           Reserva Sur                         165.0
# 7                   Opo                          66.0
# 8             Chacra 64                          39.0
# 9             Chacra 79                          88.0
# 10              Reserva                         110.0
# 11             Chacra 5                         220.0
# 12            Chacra 31                          99.0
# 13  Diecinueve de Abril                          17.0
# 14            Quinta 24                          88.0
# 15      Cancha Aviación                         275.0
#
# ...

# %%
castelli
# Out:
#     id_renabap                                           geometry  renabap_id  \
# 0         3800  MULTIPOLYGON (((-60.633038 -25.933384, -60.633...        3800
# 1         3801  MULTIPOLYGON (((-60.62953693013097 -25.9401491...        3801
# 2         3802  MULTIPOLYGON (((-60.64064869213973 -25.9325697...        3802
# 3         3803  MULTIPOLYGON (((-60.64212529890826 -25.9455916...        3803
# 4         3804  MULTIPOLYGON (((-60.64296252492487 -25.9491521...        3804
# 5         3805  MULTIPOLYGON (((-60.63664818537112 -25.9567018...        3805
# 6         3806  MULTIPOLYGON (((-60.622754 -25.954377, -60.621...        3806
# 7         3807  MULTIPOLYGON (((-60.63513906678358 -25.9639678...        3807
# 8         3808  MULTIPOLYGON (((-60.63075028995631 -25.9678003...        3808
# 9         3809  MULTIPOLYGON (((-60.61396069427951 -25.9641669...        3809
# 10        3810  MULTIPOLYGON (((-60.635548 -25.933285, -60.633...        3810
# ...

# %%
castelli['total_pobladores'] = castelli['personas_genero_fem'] + castelli['personas_genero_masc'] + castelli['personas_genero_otrx']

castelli[['nombre_barrio', 'total_pobladores']]
# Out:
# /tmp/ipykernel_365468/2385323743.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   castelli['total_pobladores'] = castelli['personas_genero_fem'] + castelli['personas_genero_masc'] + castelli['personas_genero_otrx']
#           nombre_barrio  total_pobladores
# 0              Chacra 7                87
# 1         Reserva Norte               139
# 2              Chacra 4               282
# 3             Quinta 14                90
# 4          Chacra 27/28               413
# 5             Chacra 65               160
# 6           Reserva Sur               374
# 7                   Opo               160
# 8             Chacra 64                74
# 9             Chacra 79               191
# 10              Reserva               275
# ...

# %%
castelli[['nombre_barrio','cantidad_familias_aproximada', 'recibe_asignacion_universal_por_hijo',
       'no_recibe_asignacion_universal_por_hijo',
       'no_sabe_si_recibe_asignacion_universal_por_hijo']]
# Out:
#           nombre_barrio  cantidad_familias_aproximada  \
# 0              Chacra 7                          80.0
# 1         Reserva Norte                          66.0
# 2              Chacra 4                          99.0
# 3             Quinta 14                          50.0
# 4          Chacra 27/28                         248.0
# 5             Chacra 65                          77.0
# 6           Reserva Sur                         165.0
# 7                   Opo                          66.0
# 8             Chacra 64                          39.0
# 9             Chacra 79                          88.0
# 10              Reserva                         110.0
# 11             Chacra 5                         220.0
# 12            Chacra 31                          99.0
# 13  Diecinueve de Abril                          17.0
# 14            Quinta 24                          88.0
# 15      Cancha Aviación                         275.0
#
# ...

# %%
castelli[[ 'rango_edad_0_a_4_anios',
       'rango_edad_5_a_9_anios', 'rango_edad_10_a_14_anios',
       'rango_edad_15_a_19_anios', 'rango_edad_20_a_24_anios',
       'rango_edad_25_a_29_anios', 'rango_edad_30_a_34_anios',
       'rango_edad_35_a_39_anios', 'rango_edad_40_a_44_anios',
       'rango_edad_45_a_49_anios', 'rango_edad_50_a_54_anios',
       'rango_edad_55_a_59_anios', 'rango_edad_60_a_64_anios',
       'rango_edad_65_a_69_anios', 'rango_edad_70_a_74_anios',
       'rango_edad_75_a_79_anios', 'rango_edad_80_o_mas_anios',]]
# Out:
#     rango_edad_0_a_4_anios  rango_edad_5_a_9_anios  rango_edad_10_a_14_anios  \
# 0                        0                      12                         8
# 1                        2                       8                        21
# 2                        2                      59                        46
# 3                        5                      13                         9
# 4                       14                      69                        47
# 5                        2                      25                        19
# 6                        7                      66                        45
# 7                        4                      29                        23
# 8                        0                       9                        13
# 9                        0                      37                        32
# 10                       1                      36                        44
# ...

# %%
cor = servicios.corr()

# %% [raw]
# servicios

# %%
servicios
# Out:
#           nombre_barrio  superficie_m2  \
# 0              Chacra 7          52999
# 1         Reserva Norte          24646
# 2              Chacra 4          46258
# 3             Quinta 14          44124
# 4          Chacra 27/28         137932
# 5             Chacra 65          48350
# 6           Reserva Sur         155662
# 7                   Opo          46301
# 8             Chacra 64          18723
# 9             Chacra 79          45903
# 10              Reserva          76069
# 11             Chacra 5         127931
# 12            Chacra 31          93642
# 13  Diecinueve de Abril           5102
# 14            Quinta 24          49360
# 15      Cancha Aviación         125429
#
#                                     energia_electrica  \
# 0   Conexión formal a la red con medidor domicilia...
# 1                         Conexión irregular a la red
# 2                         Conexión irregular a la red
# 3                         Conexión irregular a la red
# ...

# %%
data = castelli[['nombre_barrio','cantidad_familias_aproximada', 'recibe_asignacion_universal_por_hijo',
       'no_recibe_asignacion_universal_por_hijo',
       'no_sabe_si_recibe_asignacion_universal_por_hijo','rango_edad_0_a_4_anios',
       'rango_edad_5_a_9_anios', 'rango_edad_10_a_14_anios',
       'rango_edad_15_a_19_anios', 'rango_edad_20_a_24_anios',
       'rango_edad_25_a_29_anios', 'rango_edad_30_a_34_anios',
       'rango_edad_35_a_39_anios', 'rango_edad_40_a_44_anios',
       'rango_edad_45_a_49_anios', 'rango_edad_50_a_54_anios',
       'rango_edad_55_a_59_anios', 'rango_edad_60_a_64_anios',
       'rango_edad_65_a_69_anios', 'rango_edad_70_a_74_anios',
       'rango_edad_75_a_79_anios', 'rango_edad_80_o_mas_anios']]

# %%
castelli.columns
# Out:
# Index(['id_renabap', 'geometry', 'renabap_id', 'nombre_barrio', 'provincia',
#        'departamento', 'localidad', 'cantidad_viviendas_aproximadas',
#        'cantidad_familias_aproximada', 'decada_de_creacion',
#        'anio_de_creacion', 'energia_electrica', 'efluentes_cloacales',
#        'agua_corriente', 'cocina', 'calefaccion', 'situacion_dominial',
#        'clasificacion_barrio', 'superficie_m2', 'personas_genero_masc',
#        'personas_genero_fem', 'personas_genero_otrx',
#        'responsable_genero_masc', 'responsable_genero_fem',
#        'familia_monoparental_responsable_masculino',
#        'familia_monoparental_responsable_femenino',
#        'cantidad_certificados_entregados',
#        'recibe_asignacion_universal_por_hijo',
#        'no_recibe_asignacion_universal_por_hijo',
#        'no_sabe_si_recibe_asignacion_universal_por_hijo',
#        'tipo_propiedad_de_quienes_vieven_en_ella', 'tipo_propiedad_alquilada',
# ...

# %%
categoricas = ['nombre_barrio','energia_electrica', 'efluentes_cloacales',
       'agua_corriente', 'cocina', 'calefaccion', 'situacion_dominial',
       'clasificacion_barrio']

numericas = ['superficie_m2',  'cantidad_viviendas_aproximadas',
       'cantidad_familias_aproximada']

# %%
for car in categoricas:
    frecuencia = castelli[car].value_counts()
    df_frecuencia = pd.DataFrame({car: frecuencia.index.tolist(), 'frecuencia': frecuencia.tolist()})
    plt.figure(figsize = (15,8))
    sns.barplot(x=car, y='frecuencia', data=df_frecuencia)
    plt.show()

# %%
barr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_97493/4195123643.py in <module>
# ----> 1 barr
#
# NameError: name 'barr' is not defined

# %%
barrios['provincia'].value_counts()
# Out:
# Buenos Aires                       1933
# Santa Fe                            408
# Chaco                               401
# Misiones                            375
# Mendoza                             317
# Tucumán                             298
# Córdoba                             281
# Salta                               233
# Entre Ríos                          212
# Río Negro                           208
# Corrientes                          200
# Jujuy                               141
# Formosa                             111
# Neuquén                             102
# Santiago del Estero                  93
# San Juan                             85
# Chubut                               70
# Ciudad Autónoma de Buenos Aires      50
# Tierra del Fuego                     47
# Catamarca                            41
# San Luis                             30
# La Rioja                             24
# Santa Cruz                           22
# ...

# %%
densidad = pd.read_csv('densidad.csv')
densidad
# Out:
#                                             Provincia  \
# 0                     Ciudad Autónoma de Buenos Aires
# 1                                             Tucumán
# 2                                        Buenos Aires
# 3                                            Misiones
# 4                                            Santa Fe
# 5                                             Córdoba
# 6                                          Entre Ríos
# 7                                               Jujuy
# 8                                             Mendoza
# 9                                          Corrientes
# 10                                              Chaco
# 11                                              Salta
# 12                                           San Juan
# 13                                            Formosa
# 14                                Santiago del Estero
# 15                                            Neuquén
# ...

# %%
densidad[densidad['Provincia'] == 'Chaco']
# Out:
#    Provincia Densidad de población\nhab/km²  Población total
# 10     Chaco                           10,6          1055259

# %%
barrios.provincia.value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
densidad
# Out:
#                                             Provincia  \
# 0                     Ciudad Autónoma de Buenos Aires
# 1                                             Tucumán
# 2                                        Buenos Aires
# 3                                            Misiones
# 4                                            Santa Fe
# 5                                             Córdoba
# 6                                          Entre Ríos
# 7                                               Jujuy
# 8                                             Mendoza
# 9                                          Corrientes
# 10                                              Chaco
# 11                                              Salta
# 12                                           San Juan
# 13                                            Formosa
# 14                                Santiago del Estero
# 15                                            Neuquén
# ...

# %%
barrios[['provincia']].value_counts()
# Out:
# provincia
# Buenos Aires                       1933
# Santa Fe                            408
# Chaco                               401
# Misiones                            375
# Mendoza                             317
# Tucumán                             298
# Córdoba                             281
# Salta                               233
# Entre Ríos                          212
# Río Negro                           208
# Corrientes                          200
# Jujuy                               141
# Formosa                             111
# Neuquén                             102
# Santiago del Estero                  93
# San Juan                             85
# Chubut                               70
# Ciudad Autónoma de Buenos Aires      50
# Tierra del Fuego                     47
# Catamarca                            41
# San Luis                             30
# La Rioja                             24
# Santa Cruz                           22
# ...

# %%
barrios[barrios['provincia'] == 'Chaco'].localidad.value_counts()
# Out:
# Resistencia                     94
# Barranqueras                    38
# Fontana                         34
# Presidencia Roque Sáenz Peña    19
# Puerto Vilelas                  17
# Juan José Castelli              16
# Villa Ángela                    13
# Tres Isletas                    13
# Machagai                        10
# Pampa Del Infierno              10
# General José de San Martín       9
# Corzuela                         8
# Nueva Pompeya                    7
# Pampa Del Indio                  7
# Villa Berthet                    7
# Napenay                          6
# Puerto Tirol                     6
# Avia Terai                       6
# El Sauzalito                     6
# Los Frentones                    6
# Las Breñas                       6
# Concepción Del Bermejo           5
# Charata                          5
# Quitilipi                        5
# Coronel Du Graty                 4
# Villa Río Bermejito              4
# Miraflores                       4
# ...

# %%
densidad.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 3 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Provincia                      24 non-null     object
#  1   Densidad de población
# hab/km²  24 non-null     object
#  2   Población total                24 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 704.0+ bytes

# %%
densidad.sort_values('Población total', ascending=False)
# Out:
#                                             Provincia  \
# 2                                        Buenos Aires
# 5                                             Córdoba
# 4                                            Santa Fe
# 0                     Ciudad Autónoma de Buenos Aires
# 8                                             Mendoza
# 1                                             Tucumán
# 6                                          Entre Ríos
# 11                                              Salta
# 3                                            Misiones
# 10                                              Chaco
# 9                                          Corrientes
# 14                                Santiago del Estero
# 12                                           San Juan
# 7                                               Jujuy
# 19                                          Río Negro
# 15                                            Neuquén
# ...

# %%
401 / 1055259
# Out:
# 0.0003800014972627573

# %%
1933 / 15625084
# Out:
# 0.00012371133492786342

# %%
0.0003800014972627573 > 0.00012371133492786342
# Out:
# True

# %%
1055259 / 401
# Out:
# 2631.568578553616

# %%
15625084 / 1933
# Out:
# 8083.333678220383

# %%
3194537 / 408
# Out:
# 7829.7475490196075
